# %%
import json

# %%
def generateHTML(inputFileName, metaDict):
    metaFilename = inputFileName
    
    
    
    part1 = '''
    <html itemscope itemtype="http://schema.org/Article">
    <head>
        <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1851265180397386" crossorigin="anonymous"></script>
        <!-- Global site tag (gtag.js) - Google Analytics -->
        <script async src="https://www.googletagmanager.com/gtag/js?id=G-3KWHP1EFNP"></script>
        <script>
        window.dataLayer = window.dataLayer || [];
        function gtag(){dataLayer.push(arguments);}
        gtag('js', new Date());

        gtag('config', 'G-3KWHP1EFNP');
        </script>
        <title>Econ Longview</title>
        <meta charset="utf-8">'''
    meta = '''
        <meta property="og:title" content="''' + metaDict['displayName'] + '''"/>''' + '''
        <meta property="twitter:title" content="''' + metaDict['displayName'] + '''"/>''' + '''
        <meta itemprop="name" content="''' + metaDict['displayName'] + '''"/>'''
    
    scripts = '''
        <meta property="og:site_name" content="Econ Longview">
        <meta property="og:image"
              content="https://images.mktw.net/im-511973?size=1.777777777777778&width=800"/>
        <meta property="og:description" content="Long term macroeconomic data and charts"/>
        <meta property="og:image:width" content="400" />
        <meta property="og:image:height" content="400" />
        <meta property="og:type" content="website"/>
        <meta itemprop="description" content="Long term macroeconomic data and charts">
        <meta name="viewport" content="width=device-width, user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0">
        <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script>
        <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.1.3/dist/js/bootstrap.min.js"></script>
        <link rel="stylesheet"
              href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.3/dist/css/bootstrap.min.css">
        <script src="https://code.highcharts.com/stock/highstock.js"></script>
        <script src="https://code.highcharts.com/stock/modules/data.js"></script>
        <script src="https://code.highcharts.com/stock/modules/exporting.js"></script>
        <script src="https://code.highcharts.com/stock/modules/export-data.js"></script>
        <link rel="stylesheet"
              type="text/css"
              href="https://cdn.jsdelivr.net/gh/vaakash/socializer@2f749eb/css/socializer.min.css">
        <link rel="stylesheet"
              href="https://use.fontawesome.com/releases/v5.15.3/css/all.css">
    '''

    part2 = '''<script src="/macroview/data/'''

    part4 = '''"></script>'''
    
    dataString = part2 + metaFilename + part4



    part5 = '''
    <script src="/macroview/charts.js"></script>
        <script>
                $(document).ready(function() {
                    $("#nav").load("/macroview/nav.html");
                    $("#menu").load("/macroview/menu.html");
                    $("#related").load("/macroview/relatedInstruments.html");
                    $("#bottom").load("/macroview/bottom.html");
                });
        </script>
        <script>
                window.onload = function(){
                    document.getElementById("currentUpdate").innerHTML = meta["currentUpdate"];
                    document.getElementById("currentValue").innerHTML = meta["currentValue"].toFixed(2);
                    document.getElementById("min").innerHTML = meta["minValue"].toFixed(2) + ' (' + meta["minDate"] + ')';
                    document.getElementById("max").innerHTML = meta["maxValue"].toFixed(2) + ' (' + meta["maxDate"] + ')';
                    document.getElementById("lastUpdate").innerHTML = meta["lastUpdate"];
                    document.getElementById("source").innerHTML = meta["source"];
                };
        </script>
    </head>
    <body>
        <!-- Google Tag Manager (noscript) -->
        <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NKSWDG6"
        height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
        <!-- End Google Tag Manager (noscript) -->
        <!-- Navigation bar -->
        <div id="nav"></div>
        <p>
        </p>
        <div class="container-fluid p-3">
            <div class="row">
                <!--
                <div class="col-2">
                    <div id="menu" class="sticky-top"></div>
                </div>
                -->
                <div class="col">
                    <!-- Main body -->
                    <div id="container" style="width:100%; height:400px;"></div>
                    <b>''' + metaDict['displayName'] + '''
                    </b>''' + metaDict['des'] + '''
                    <b></b>
                    <table class="table table-sm table-hover">
                        <tbody>
                            <tr>
                                <th scope="row" style="width: 25%">Data history ranged between</th>
                                <td>''' + metaDict['dataFrom'] + ' - ' + metaDict["dataTo"] + '''    
                                </td>
                            </tr>
                            <tr>
                                <th scope="row">Current update</th>
                                <td>
                                    <div id="currentUpdate"></div>
                                </td>
                            </tr>
                            <tr>
                                <th scope="row">Current value</th>
                                <td>
                                    <div id="currentValue"></div>
                                </td>
                            </tr>
                            <tr>
                                <th scope="row">Min</th>
                                <td>
                                    <div id="min"></div>
                                </td>
                            </tr>
                            <tr>
                                <th scope="row">Max</th>
                                <td>
                                    <div id="max"></div>
                                </td>
                            </tr>
                            <tr>
                                <th scope="row">Last update</th>
                                <td>
                                    <div id="lastUpdate"></div>
                                </td>
                            </tr>
                            <tr>
                                <th scope="row">Source</th>
                                <td>
                                    <div id="source"></div>
                                </td>
                            </tr>
                        </tbody>
                    </table>
                    <!-- AD -->
                    <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1851265180397386" crossorigin="anonymous"></script>
                    <!-- sq -->
                    <ins class="adsbygoogle"
                        style="display:block"
                        data-ad-client="ca-pub-1851265180397386"
                        data-ad-slot="7546310738"
                        data-ad-format="auto"
                        data-full-width-responsive="true"></ins>
                    <script>(adsbygoogle = window.adsbygoogle || []).push({});</script>
                    <!-- End AD -->
                    <p>
                    </p>
                    <!-- Social buttons -->
                    <div class="socializer"
                         data-features="32px,circle,opacity,icon-dark,bg-white,pad"
                         data-sites="facebook,twitter,linkedin,discord,reddit,email,whatsapp">
                    </div>
                    <script src="https://cdn.jsdelivr.net/gh/vaakash/socializer@2f749eb/js/socializer.min.js"></script>
                    <script>
                (function(){
                    socializer( '.socializer' );
                }());
                    </script>
                    <!-- Footer -->
                    <p>
                    </p>
                    <hr>
                    <div id="related">
                    </div>
                </div>
            </div>
            <p>
            </p>
            <!-- AD -->
                    <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1851265180397386" crossorigin="anonymous"></script>
                    <!-- sq -->
                    <ins class="adsbygoogle"
                        style="display:block"
                        data-ad-client="ca-pub-1851265180397386"
                        data-ad-slot="7546310738"
                        data-ad-format="auto"
                        data-full-width-responsive="true"></ins>
                    <script>(adsbygoogle = window.adsbygoogle || []).push({});</script>
                    <!-- End AD -->
            <div id="bottom">
            </div>
        </body>
    </html>

    '''

    htmlFileName = metaFilename.replace('meta_', 'page_').replace('.js', '.html')
    file = open("page/"+htmlFileName,"w")
    file.write(part1+meta+scripts+dataString+part5)
    file.close()

# %%
import os

files = os.listdir('data')




for f in files:
    if f.endswith(".js"):
        print(f)
        tf = open('data/' + f.replace('.js', '') + '.json', "r")
        metaDict = json.load(tf)
        generateHTML(str(f),metaDict)
# Out:
# meta_000001.SS.js
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-516288463768> in <module>
#      11         tf = open('data/' + f.replace('.js', '') + '.json', "r")
#      12         metaDict = json.load(tf)
# ---> 13         generateHTML(str(f),metaDict)
#
# <ipython-input-5-f78d56226eb2> in generateHTML(inputFileName, metaDict)
#      98                     <div id="container" style="width:100%; height:400px;"></div>
#      99                     <b>''' + metaDict['displayName'] + '''
# --> 100                     </b>''' + metaDict['des'] + '''
#     101                     <b></b>
#     102                     <table class="table table-sm table-hover">
#
# KeyError: 'des'
