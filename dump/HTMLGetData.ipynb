# %%
import nasdaqdatalink
import quandl

# %%
def generateJSVar(df, varName, fieldName, isX = True):
    init = 'var ' + varName + ' = ["' + varName + '",'
    s = ''
    
    for i in range(len(df)):
        if isX == True:
            s = s + '"' + str(df.loc[i, fieldName].strftime('%Y-%m-%d')) + '",'
        else:
            s = s + '"' + str(df.loc[i, fieldName]) + '",'
    
    s = init + s + "]"
    
    return s

def GenerateHighchartVar(df, fieldX, fieldY):
    df = df.tail(990)
    init = '[' + '\n'
    s = ''
    
    for i in range(len(df)):
        s = s + '[' + str(df.loc[i, fieldX].timestamp() * 1000) + ',' + str(df.loc[i, fieldY]) + '],' + '\n'
    
    s = init + s + "]"
    
    return s

def generateJSDataFile(fileName, content):
    with open(fileName+ ".json", "w") as outfile:
        outfile.write(content)

# %%
mydata = quandl.get("MULTPL/SHILLER_PE_RATIO_MONTH")
mydata
# Out:
#             Value
# Date
# 1871-02-01  10.92
# 1871-03-01  11.19
# 1871-04-01  12.05
# 1871-05-01  12.59
# 1871-06-01  12.59
# ...           ...
# 2022-01-01  37.47
# 2022-01-31  37.31
# 2022-02-01  37.54
# 2022-02-28  35.80
# 2022-03-01  35.25
#
# [1835 rows x 1 columns]

# %%
myNewData = mydata.reset_index()

# %%
x = generateJSVar(myNewData, 'x1', 'Date', isX=True)
y = generateJSVar(myNewData, 'data1','Value', isX=False)
generateJSDataFile('SHILLER_PE_RATIO_MONTH',[x,y])

# %%
data = GenerateHighchartVar(myNewData, 'Date','Value')
generateJSDataFile('data_SHILLER_PE_RATIO_MONTH', data)

# %%
from yahoo_fin import stock_info as si
a = si.get_data("CL=F")

# %%
a
# Out:
#                   open        high         low       close    adjclose  \
# 2000-08-23   31.950001   32.799999   31.950001   32.049999   32.049999
# 2000-08-24   31.900000   32.240002   31.400000   31.629999   31.629999
# 2000-08-25   31.700001   32.099998   31.320000   32.049999   32.049999
# 2000-08-28   32.040001   32.919998   31.860001   32.869999   32.869999
# 2000-08-29   32.820000   33.029999   32.560001   32.720001   32.720001
# ...                ...         ...         ...         ...         ...
# 2022-03-15  102.279999  102.580002   93.529999   96.440002   96.440002
# 2022-03-16   95.230003   99.220001   94.070000   95.040001   95.040001
# 2022-03-17   95.339996  104.239998   94.849998  102.980003  102.980003
# 2022-03-18  103.620003  106.279999  102.300003  104.699997  104.699997
# 2022-03-21  105.129997  112.690002  104.080002  112.120003  112.120003
#
#               volume ticker
# 2000-08-23   79385.0   CL=F
# 2000-08-24   72978.0   CL=F
# 2000-08-25   44601.0   CL=F
# 2000-08-28   46770.0   CL=F
# 2000-08-29   49131.0   CL=F
# ...              ...    ...
# 2022-03-15  401690.0   CL=F
# 2022-03-16  293947.0   CL=F
# 2022-03-17  210763.0   CL=F
# 2022-03-18   74247.0   CL=F
# 2022-03-21   74247.0   CL=F
#
# [5494 rows x 7 columns]

# %%
a['close']
# Out:
# 2000-08-23     32.049999
# 2000-08-24     31.629999
# 2000-08-25     32.049999
# 2000-08-28     32.869999
# 2000-08-29     32.720001
#                  ...
# 2022-03-15     96.440002
# 2022-03-16     95.040001
# 2022-03-17    102.980003
# 2022-03-18    104.699997
# 2022-03-21    112.120003
# Name: close, Length: 5494, dtype: float64

# %%
a_reset = a['close'].reset_index()

# %%
a_reset
# Out:
#           index       close
# 0    2000-08-23   32.049999
# 1    2000-08-24   31.629999
# 2    2000-08-25   32.049999
# 3    2000-08-28   32.869999
# 4    2000-08-29   32.720001
# ...         ...         ...
# 5489 2022-03-15   96.440002
# 5490 2022-03-16   95.040001
# 5491 2022-03-17  102.980003
# 5492 2022-03-18  104.699997
# 5493 2022-03-21  112.120003
#
# [5494 rows x 2 columns]

# %%
x = generateJSVar(a_reset, 'x1', 'index', isX=True)
y = generateJSVar(a_reset, 'data1','close', isX=False)
generateJSDataFile('data_cl1',[x,y])

# %%
vix = si.get_data('%5EVIX')
vix_reset = vix['close'].reset_index()
vix_reset
# Out:
#           index      close
# 0    1990-01-02  17.240000
# 1    1990-01-03  18.190001
# 2    1990-01-04  19.219999
# 3    1990-01-05  20.110001
# 4    1990-01-08  20.260000
# ...         ...        ...
# 8114 2022-03-16  26.670000
# 8115 2022-03-17  25.670000
# 8116 2022-03-18  23.870001
# 8117 2022-03-21  23.530001
# 8118 2022-03-21  23.530001
#
# [8119 rows x 2 columns]

# %%
x = generateJSVar(vix_reset, 'x1', 'index', isX=True)
y = generateJSVar(vix_reset, 'data1','close', isX=False)
generateJSDataFile('data_vix',[x,y])

# %%
t = quandl.get("USTREASURY/YIELD")

# %%
t
# Out:
#             1 MO  2 MO  3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  7 YR  10 YR  \
# Date
# 1990-01-02   NaN   NaN  7.83  7.89  7.81  7.87  7.90  7.87  7.98   7.94
# 1990-01-03   NaN   NaN  7.89  7.94  7.85  7.94  7.96  7.92  8.04   7.99
# 1990-01-04   NaN   NaN  7.84  7.90  7.82  7.92  7.93  7.91  8.02   7.98
# 1990-01-05   NaN   NaN  7.79  7.85  7.79  7.90  7.94  7.92  8.03   7.99
# 1990-01-08   NaN   NaN  7.79  7.88  7.81  7.90  7.95  7.92  8.05   8.02
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 2022-01-31  0.03  0.13  0.22  0.49  0.78  1.18  1.39  1.62  1.75   1.79
# 2022-02-01  0.04  0.10  0.19  0.48  0.78  1.18  1.39  1.63  1.76   1.81
# 2022-02-02  0.04  0.10  0.19  0.45  0.76  1.16  1.38  1.60  1.74   1.78
# 2022-02-03  0.03  0.15  0.20  0.48  0.78  1.19  1.42  1.66  1.78   1.82
# 2022-02-04  0.05  0.12  0.23  0.56  0.89  1.31  1.55  1.78  1.90   1.93
#
#             20 YR  30 YR
# Date
# 1990-01-02    NaN   8.00
# 1990-01-03    NaN   8.04
# 1990-01-04    NaN   8.04
# 1990-01-05    NaN   8.06
# 1990-01-08    NaN   8.09
# ...           ...    ...
# 2022-01-31   2.17   2.11
# 2022-02-01   2.19   2.12
# 2022-02-02   2.17   2.11
# 2022-02-03   2.20   2.14
# 2022-02-04   2.29   2.23
#
# [8032 rows x 12 columns]

# %%
from fredapi import Fred
fred = Fred(api_key='d79cebb1e12819cd44ed96cc291f0f72')

# %%
yieldSpread = fred.get_series('T10Y2Y')
yieldSpread_reset = yieldSpread.reset_index()
yieldSpread_reset.columns = ['Date','Value']
x = generateJSVar(yieldSpread_reset, 'x1', 'Date', isX=True)
y = generateJSVar(yieldSpread_reset, 'data1','Value', isX=False)
generateJSDataFile('data_T10Y2Y',[x,y])

# %%
coreCPI = fred.get_series('CPILFESL')
coreCPIYOY = coreCPI.pct_change(periods=12)*100
coreCPIYOY
# Out:
# 1957-01-01         NaN
# 1957-02-01         NaN
# 1957-03-01         NaN
# 1957-04-01         NaN
# 1957-05-01         NaN
#                 ...
# 2021-10-01    4.593958
# 2021-11-01    4.952634
# 2021-12-01    5.476621
# 2022-01-01    6.040783
# 2022-02-01    6.415744
# Length: 782, dtype: float64

# %%
coreCPIYOY_reset = coreCPIYOY.reset_index()
coreCPIYOY_reset.columns = ['Date','Value']
x = generateJSVar(coreCPIYOY_reset, 'x1', 'Date', isX=True)
y = generateJSVar(coreCPIYOY_reset, 'data1','Value', isX=False)
generateJSDataFile('data_coreCPIYOY',[x,y])

# %%
realYield = fred.get_series('DFII10')
realYield
# Out:
# 2003-01-02    2.43
# 2003-01-03    2.43
# 2003-01-06    2.46
# 2003-01-07    2.42
# 2003-01-08    2.29
#               ...
# 2022-03-15   -0.69
# 2022-03-16   -0.61
# 2022-03-17   -0.71
# 2022-03-18   -0.72
# 2022-03-21   -0.58
# Length: 5013, dtype: float64

# %%
realYield_reset = realYield.reset_index()
realYield_reset.columns = ['Date','Value']
x = generateJSVar(realYield_reset, 'x1', 'Date', isX=True)
y = generateJSVar(realYield_reset, 'data1','Value', isX=False)
generateJSDataFile('data_realYield',[x,y])

# %%
# https://colab.research.google.com/drive/1S7bAG8HAJ6B-KkWlClmeOAc9V9HJOPZB?usp=sharing#scrollTo=ti8GH8YikINi

import yfinance as yf
import pandas as pd
payload = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
sp500_table = payload[0]
sp500_table
# Out:
#     Symbol       Security SEC filings             GICS Sector  \
# 0      MMM             3M     reports             Industrials
# 1      AOS    A. O. Smith     reports             Industrials
# 2      ABT         Abbott     reports             Health Care
# 3     ABBV         AbbVie     reports             Health Care
# 4     ABMD        Abiomed     reports             Health Care
# ..     ...            ...         ...                     ...
# 500    YUM    Yum! Brands     reports  Consumer Discretionary
# 501   ZBRA          Zebra     reports  Information Technology
# 502    ZBH  Zimmer Biomet     reports             Health Care
# 503   ZION  Zions Bancorp     reports              Financials
# 504    ZTS         Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota
# 1                     Building Products     Milwaukee, Wisconsin
# 2                 Health Care Equipment  North Chicago, Illinois
# 3                       Pharmaceuticals  North Chicago, Illinois
# 4                 Health Care Equipment   Danvers, Massachusetts
# ..                                  ...                      ...
# 500                         Restaurants     Louisville, Kentucky
# 501  Electronic Equipment & Instruments   Lincolnshire, Illinois
# 502               Health Care Equipment          Warsaw, Indiana
# 503                      Regional Banks     Salt Lake City, Utah
# 504                     Pharmaceuticals   Parsippany, New Jersey
#
#     Date first added      CIK      Founded
# 0         1976-08-09    66740         1902
# 1         2017-07-26    91142         1916
# 2         1964-03-31     1800         1888
# 3         2012-12-31  1551152  2013 (1888)
# 4         2018-05-31   815094         1981
# ..               ...      ...          ...
# 500       1997-10-06  1041061         1997
# 501       2019-12-23   877212         1969
# 502       2001-08-07  1136869         1927
# 503       2001-06-22   109380         1873
# 504       2013-06-21  1555280         1952
#
# [505 rows x 9 columns]

# %%
sp500_tickers = sp500_table.Symbol.str.upper().values
sp500_names = sp500_table.Security.values
sp500_sectors = sp500_table["GICS Sector"].values
sp500_sub_sectors = sp500_table["GICS Sub-Industry"].values

sp500_names_mapping = dict(zip(sp500_tickers, sp500_names))
sp500_sector_mapping = dict(zip(sp500_names, sp500_sectors))
sp500_sub_sector_mapping = dict(zip(sp500_names, sp500_sub_sectors))

# %%
tickers = list(sp500_tickers)
prices = yf.download(tickers, start="2020-01-01", end="2021-12-31", interval='1d')
prices = prices["Adj Close"]
prices = prices.rename(columns=sp500_names_mapping)
prices
# Out:
# [*********************100%***********************]  505 of 505 completed
#
# 3 Failed downloads:
# - CEG: Data doesn't exist for startDate = 1577808000, endDate = 1640880000
# - BF.B: No data found for this date range, symbol may be delisted
# - BRK.B: No data found, symbol may be delisted
#             Agilent Technologies  American Airlines Group  Advance Auto Parts  \
# Date
# 2019-12-31             84.168228                28.574404          155.080658
# 2020-01-02             84.799675                28.982893          154.354446
# 2020-01-03             83.438148                27.548195          154.364105
# 2020-01-06             83.684799                27.219410          151.827209
# 2020-01-07             83.941315                27.119778          150.026199
# ...                          ...                      ...                 ...
# 2021-12-23            157.592438                18.260000          230.452118
# 2021-12-27            158.531204                18.170000          234.790527
# 2021-12-28            158.970612                18.540001          236.408752
# 2021-12-29            160.438675                18.049999          239.287781
# 2021-12-30            160.668396                18.070000          235.803162
#
#                  Apple      AbbVie  AmerisourceBergen     Abiomed      Abbott  \
# Date
# 2019-12-31   72.245934   79.233513          82.006271  170.589996   83.914215
# 2020-01-02   73.894325   80.137344          82.064148  168.809998   84.001175
# 2020-01-03   73.175926   79.376694          81.032066  166.820007   82.977112
# 2020-01-06   73.759010   80.003113          82.218460  179.039993   83.411858
# 2020-01-07   73.412117   79.546722          81.630089  180.350006   82.948143
# ...                ...         ...                ...         ...         ...
# 2021-12-23  176.055695  131.723129         129.109039  352.209991  138.670883
# 2021-12-27  180.100540  133.029587         131.471329  357.829987  140.962799
# 2021-12-28  179.061859  133.009781         131.929840  357.440002  139.976273
# 2021-12-29  179.151749  133.969818         132.906647  361.839996  140.693741
# 2021-12-30  177.973251  134.533966         133.335266  362.059998  140.504410
#
#              Accenture       Adobe  ...  Wynn Resorts  Xcel Energy  \
# Date                                ...
# 2019-12-31  204.183365  329.809998  ...    137.714386    59.756420
# 2020-01-02  203.776093  334.429993  ...    142.405029    58.711700
# 2020-01-03  203.436752  331.809998  ...    140.292755    58.994057
# 2020-01-06  202.108246  333.709991  ...    140.015091    58.909351
# 2020-01-07  197.744751  333.390015  ...    140.679504    58.786999
# ...                ...         ...  ...           ...          ...
# 2021-12-23  402.267090  569.619995  ...     88.879997    66.148552
# 2021-12-27  414.255981  577.679993  ...     87.580002    66.357094
# 2021-12-28  414.196136  569.359985  ...     86.459999    67.151550
# 2021-12-29  414.345795  569.289978  ...     84.980003    67.489197
# 2021-12-30  412.759857  570.530029  ...     86.150002    67.757332
#
#             ExxonMobil  Dentsply Sirona       Xylem  Yum! Brands  \
# Date
# 2019-12-31   60.208515        55.656384   76.772598    96.749886
# 2020-01-02   61.174896        55.990772   77.805458    98.132988
# 2020-01-03   60.683079        55.371174   78.263420    97.825638
# 2020-01-06   61.149021        55.676060   77.756729    97.768013
# 2020-01-07   60.648567        55.971111   77.464401    97.940918
# ...                ...              ...         ...          ...
# 2021-12-23   60.350952        55.322369  117.112770   134.714600
# 2021-12-27   61.211414        55.841362  117.900162   137.372253
# 2021-12-28   61.013607        55.921204  119.126106   137.342392
# 2021-12-29   60.479530        56.540001  118.966637   138.019257
# 2021-12-30   60.123474        56.200001  118.707489   137.750504
#
#             Zimmer Biomet       Zebra  Zions Bancorp      Zoetis
# Date
# 2019-12-31     143.179916  255.440002      48.534744  130.665115
# 2020-01-02     142.720795  259.140015      49.020840  132.432312
# 2020-01-03     142.347702  256.049988      48.329098  132.452057
# 2020-01-06     141.525040  258.010010      47.740170  131.435196
# 2020-01-07     141.400711  256.470001      47.450382  131.879440
# ...                   ...         ...            ...         ...
# 2021-12-23     123.051254  582.409973      62.041107  242.121170
# 2021-12-27     124.087379  606.330017      62.687782  246.114746
# 2021-12-28     124.475731  597.320007      62.787273  243.858383
# 2021-12-29     124.495148  601.119995      63.125534  246.633926
# 2021-12-30     124.533981  597.539978      62.807171  244.766922
#
# [505 rows x 505 columns]

# %%
prices.to_csv('sp500prices.csv')

# %%
import investpy
data = investpy.economic_calendar(from_date='01/03/2022', to_date='01/09/2022')
data
# Out:
#        id        date     time         zone currency importance  \
# 0     173  01/03/2022  All Day  south korea     None       None
# 1     202  01/03/2022  All Day    argentina     None       None
# 2     202  01/03/2022  All Day       brazil     None       None
# 3     202  01/03/2022  All Day    venezuela     None       None
# 4     202  01/03/2022  All Day      ecuador     None       None
# ...   ...         ...      ...          ...      ...        ...
# 2911  216  31/08/2022  All Day     malaysia     None       None
# 2912  247  31/08/2022  All Day        india     None       None
# 2913  178  01/09/2022  All Day     slovakia     None       None
# 2914  215  01/09/2022  All Day      vietnam     None       None
# 2915  247  01/09/2022  All Day    mauritius     None       None
#
#                                event actual forecast previous
# 0     South Korea - Independence Day   None     None     None
# 1               Argentina - Carnival   None     None     None
# 2                  Brazil - Carnival   None     None     None
# 3               Venezuela - Carnival   None     None     None
# 4                 Ecuador - Carnival   None     None     None
# ...                              ...    ...      ...      ...
# 2911         Malaysia - National Day   None     None     None
# 2912        India - Ganesh Chaturthi   None     None     None
# 2913     Slovakia - Constitution Day   None     None     None
# 2914        Vietnam - Public Holiday   None     None     None
# 2915    Mauritius - Ganesh Chaturthi   None     None     None
#
# [2916 rows x 10 columns]

# %%
dvdYield = quandl.get("MULTPL/SP500_DIV_YIELD_MONTH")
dvdYield
# Out:
#             Value
# Date
# 1871-01-31   5.86
# 1871-02-28   5.78
# 1871-03-31   5.64
# 1871-04-30   5.49
# 1871-05-31   5.35
# ...           ...
# 2021-12-31   1.29
# 2022-01-31   1.32
# 2022-02-01   1.33
# 2022-02-28   1.32
# 2022-03-01   1.40
#
# [1834 rows x 1 columns]

# %%
f = dvdYield
dataFileName = 'dvdYield'
f_reset = f.reset_index()
f_reset.columns = ['Date','Value']
x = generateJSVar(f_reset, 'x1', 'Date', isX=True)
y = generateJSVar(f_reset, 'data1','Value', isX=False)
generateJSDataFile('data_'+ dataFileName,[x,y])

# %%
import dbnomics
worldGDP = dbnomics.fetch_series('WB', 'WDI', 'NY.GDP.MKTP.KD.ZG-1W')
worldGDP
# Out:
#    @frequency provider_code dataset_code                  dataset_name  \
# 0      annual            WB          WDI  World Development Indicators
# 1      annual            WB          WDI  World Development Indicators
# 2      annual            WB          WDI  World Development Indicators
# 3      annual            WB          WDI  World Development Indicators
# 4      annual            WB          WDI  World Development Indicators
# ..        ...           ...          ...                           ...
# 56     annual            WB          WDI  World Development Indicators
# 57     annual            WB          WDI  World Development Indicators
# 58     annual            WB          WDI  World Development Indicators
# 59     annual            WB          WDI  World Development Indicators
# 60     annual            WB          WDI  World Development Indicators
#
#              series_code                    series_name original_period  \
# 0   NY.GDP.MKTP.KD.ZG-1W  GDP growth (annual %) – World            1960
# 1   NY.GDP.MKTP.KD.ZG-1W  GDP growth (annual %) – World            1961
# 2   NY.GDP.MKTP.KD.ZG-1W  GDP growth (annual %) – World            1962
# 3   NY.GDP.MKTP.KD.ZG-1W  GDP growth (annual %) – World            1963
# 4   NY.GDP.MKTP.KD.ZG-1W  GDP growth (annual %) – World            1964
# ..                   ...                            ...             ...
# 56  NY.GDP.MKTP.KD.ZG-1W  GDP growth (annual %) – World            2016
# 57  NY.GDP.MKTP.KD.ZG-1W  GDP growth (annual %) – World            2017
# 58  NY.GDP.MKTP.KD.ZG-1W  GDP growth (annual %) – World            2018
# 59  NY.GDP.MKTP.KD.ZG-1W  GDP growth (annual %) – World            2019
# 60  NY.GDP.MKTP.KD.ZG-1W  GDP growth (annual %) – World            2020
#
#        period original_value     value          indicator country  \
# 0  1960-01-01             NA       NaN  NY.GDP.MKTP.KD.ZG      1W
# 1  1961-01-01        3.80083  3.800832  NY.GDP.MKTP.KD.ZG      1W
# 2  1962-01-01        5.32028  5.320280  NY.GDP.MKTP.KD.ZG      1W
# 3  1963-01-01        5.19242  5.192421  NY.GDP.MKTP.KD.ZG      1W
# 4  1964-01-01        6.56875  6.568749  NY.GDP.MKTP.KD.ZG      1W
# ..        ...            ...       ...                ...     ...
# 56 2016-01-01        2.82457  2.824569  NY.GDP.MKTP.KD.ZG      1W
# 57 2017-01-01        3.39464  3.394638  NY.GDP.MKTP.KD.ZG      1W
# 58 2018-01-01         3.2627  3.262697  NY.GDP.MKTP.KD.ZG      1W
# 59 2019-01-01        2.60215  2.602147  NY.GDP.MKTP.KD.ZG      1W
# 60 2020-01-01        -3.3626 -3.362598  NY.GDP.MKTP.KD.ZG      1W
#
#         indicator (label) country (label)
# 0   GDP growth (annual %)           World
# 1   GDP growth (annual %)           World
# 2   GDP growth (annual %)           World
# 3   GDP growth (annual %)           World
# 4   GDP growth (annual %)           World
# ..                    ...             ...
# 56  GDP growth (annual %)           World
# 57  GDP growth (annual %)           World
# 58  GDP growth (annual %)           World
# 59  GDP growth (annual %)           World
# 60  GDP growth (annual %)           World
#
# [61 rows x 14 columns]

# %%
worldGDP[['period','value']]
# Out:
#        period     value
# 0  1960-01-01       NaN
# 1  1961-01-01  3.800832
# 2  1962-01-01  5.320280
# 3  1963-01-01  5.192421
# 4  1964-01-01  6.568749
# ..        ...       ...
# 56 2016-01-01  2.824569
# 57 2017-01-01  3.394638
# 58 2018-01-01  3.262697
# 59 2019-01-01  2.602147
# 60 2020-01-01 -3.362598
#
# [61 rows x 2 columns]

# %%
f = worldGDP[['period','value']]
dataFileName = 'worldGDP'
x = generateJSVar(f_reset, 'x1', 'period', isX=True)
y = generateJSVar(f_reset, 'data1','value', isX=False)
generateJSDataFile('data_'+ dataFileName,[x,y])
